# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in c:\users\hak3\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\hak3\anaconda3\lib\site-packages (from vaderSentiment) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hak3\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hak3\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hak3\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hak3\anaconda3\lib\site-packages (from requests->vaderSentiment) (2025.4.26)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def sentiment_scores(sentence):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(sentence)

    print(f"Sentiment Scores: {sentiment_dict}")
    print(f"Negative Sentiment: {sentiment_dict['neg']*100}%")
    print(f"Neutral Sentiment: {sentiment_dict['neu']*100}%")
    print(f"Positive Sentiment: {sentiment_dict['pos']*100}%")
    
    if sentiment_dict['compound'] >= 0.05:
        print("Overall Sentiment: Positive")
    elif sentiment_dict['compound'] <= -0.05:
        print("Overall Sentiment: Negative")
    else:
        print("Overall Sentiment: Neutral")

# %%
if __name__ == "__main__":

    print("\n1st Statement:")
    sentence = "Geeks For Geeks is an excellent platform for CSE students."
    sentiment_scores(sentence)
# Out:
# 1st Statement:
# Sentiment Scores: {'neg': 0.207, 'neu': 0.519, 'pos': 0.274, 'compound': 0.4404}
# Negative Sentiment: 20.7%
# Neutral Sentiment: 51.9%
# Positive Sentiment: 27.400000000000002%
# Overall Sentiment: Positive

# %%
print("\n2nd Statement:")
sentence = "Shweta played well in the match as usual."
sentiment_scores(sentence)
# Out:
# 2nd Statement:
# Sentiment Scores: {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.5423}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.099999999999994%
# Positive Sentiment: 42.9%
# Overall Sentiment: Positive

# %%
print("\n3rd Statement:")
sentence = "I am feeling sad today."
sentiment_scores(sentence)
# Out:
# 3rd Statement:
# Sentiment Scores: {'neg': 0.408, 'neu': 0.395, 'pos': 0.197, 'compound': -0.3818}
# Negative Sentiment: 40.8%
# Neutral Sentiment: 39.5%
# Positive Sentiment: 19.7%
# Overall Sentiment: Negative

# %%
print("\n4rd Statement:")
sentence = "go away ."
sentiment_scores(sentence)
# Out:
# 4rd Statement:
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 100.0%
# Positive Sentiment: 0.0%
# Overall Sentiment: Neutral

# %%
print("\n3rd Statement:")
sentence = "I don't want to see you."
sentiment_scores(sentence)
# Out:
# 3rd Statement:
# Sentiment Scores: {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.0572}
# Negative Sentiment: 19.6%
# Neutral Sentiment: 80.4%
# Positive Sentiment: 0.0%
# Overall Sentiment: Negative
